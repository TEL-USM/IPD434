# %% [markdown]
# <img src="images/utfsm.png" alt="" width="150px" align="left"/>
# <img src="images/utfsm.png" alt="" width="150px" align="right"/>
# <br/>
# <div align="center">
# <h2>IPD-434 Seminario de Soft Computing</h2><br/>
# <h1>Introducción a Soft Computing</h1>
# <br/><br/>
# Dr. Nicolás Gálvez Ramírez<br/>
# Dr. Patricio Olivares Roncagliolo<br/><br/>
# Departamento de Eléctronica<br/>
# Universidad Técnica Federico Santa María
# </div>

# %% [markdown]
# # Soft Computing

# %% [markdown]
# - El término **Soft Computing** fue introducidor por Lotfi A. Zadeh.
# - Soft Computing es un conjunto de técnicas capaces de resolver **problemas de alta complejidad** con técnicas **imprecisas o incompletas**.

# %% [markdown]
# # Ejemplos

# %% [markdown]
# #### Estacionar automóvil en un espacio estrecho
#
# No se necesitan las dimensiones **exactas** del espacio o del automóvil.

# %% [markdown]
# #### Reconocer caracteres escritos a mano
#
# Aunque las letras escritas a mano no sigan su forma ideal, igualmente **somos capaces de reconocerlos**.

# %% [markdown]
# #### Hormigas recolectando comida
#
# Inicialmente las hormigas buscan comida aleatoriamente. Cuando  una de ellas encuentra comida, **comparte el mensaje** con el resto para que todas se dirijan a la fuente de alimento.

# %% [markdown]
# # Componentes de Soft Computing

# %% [markdown]
# - Sistemas difusos.
# - Estrategias en espacio de búsqueda.
# - Computación evolutiva y bioinspirada.
# - Redes Neuronales Artificiales.
# - Sistemas híbridos.

# %% [markdown]
# # Conceptos importantes

# %% [markdown]
# ## Espacio de Estados o de Búsqueda

# %% [markdown]
# - Corresponde al conjunto, discreto, de estados o configuraciones posibles para un sistema.
#     * Cantidad de soluciones (factibles e infactibles) de un problema.
#     * Cantidad de posibles recomendaciones que una ANN puede entregar.

# %% [markdown]
# - Define la dificultad de un problema.
#     * Conjunto finito de tamaño constante.
#     * Conjunto finito de gran tamaño.
#     * Conjunto finito creciente.

# %% [markdown]
# - Búsqueda: desde un **estado inicial** hacia un **estado final**.
#     * Este estado final se define en base al problema a abordar o resolver.
#     * Transformaciones que llevan desde un estadio inicial a uno final.

# %% [markdown]
# ## Tipos de Búsqueda

# %% [markdown]
# * Búsqueda Completa: Busca el mejor elemento global en todo el espacio de estados/búsqueda.
#     * Hard Computing.
# * Búsqueda Incompleta: Busca mejor elemento local en una aproximación del espacio de estados/búsqueda.
#     * Soft Computing

# %% [markdown]
#  # Complejidad Computacional de Problemas

# %% [markdown]
# ## Problema de Decisión
#
# * Problema con resultado binario: Sí o No?
#     * ¿Se puede decidir si un número n es primo?
#     * ¿Se puede decidir si los primeros n números naturales son primos?
#
# * Buscamos: Clases de problemas.

# %% [markdown]
# ## Clase P
#
# - Conjunto de problemas de decisión, que pueden ser resueltos por una **Maquina de Turing** _determinista_ en tiempo polinomial.
#     * Informalmente: Problemas que pueden ser resueltos por un algoritmo determinista en tiempo polinomial.
#     * Determinista: algoritmo que sigue siempre pasos conocidos.
#     * Un algoritmo resuelve diferentes instancias de distintos problemas tipo P.
#     * P = Polynomial.

# %% [markdown]
# ## Clase NP
#
# - Los **problemas NP** (de sus siglas en inglés Nondeterministic Polynomial time) son aquellos en los que, dada una solución, esta se puede verificar en tiempo polinomial. Los problemas NP no necesariamente han sido resueltos en tiempo polinomial.
#
# El problema **P vs NP** intenta determinar si el conjunto **P** es igual al conjunto **NP**. Vale decir, **¿es todo problema que se pueda verificar en tiempo polinomial también ser resuelto en tiempo polinomial?** (aún sin respuestaClasa

# %% [markdown]
# ## NP-Complete

# %% [markdown]
# **NP-Completo** son aquellos problemas de tipo NP tales que cualquier problema NP puede ser traducido a este en tiempo polinomial.

# %% [markdown]
# ## NP-Hard

# %% [markdown]
# Se les llama problemas **NP-Hard** a aquellos que, si bien no necesariamente se encuentran en el conjunto NP, pueden llegar a ser tan difíciles como los problemas más complejos de NP.

# %% [markdown]
# ## ¿P = NP?

# %% [markdown]
# <img width="80%" src="images/p_np.svg" alt="" />
