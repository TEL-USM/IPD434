# %% [markdown]
# <br/>
# <img src="images/utfsm.png" alt="" width="130px" align="left"/>
# <img src="images/utfsm.png" alt="" width="130px" align="right"/>
# <div align="center">
# <h1>Deep Reinforcement Learning</h1>
# <br/><br/>
# Dr. Nicolás Gálvez Ramírez<br/>
# Dr. Patricio Olivares Roncagliolo<br/><br/>
# Ingeniería Civil Telemática<br/>
# Departamento de Eléctronica<br/>
# Universidad Técnica Federico Santa María
# </div>
# <br>
# Fuentes:
# <br>
# "Hands-on Machine Learning with Scikit-Learn, Keras & TensorFlow"
# <br>
# "Standford - CS229 Notes"

# %% [markdown]
# # RL - Reinforcement Learning (Aprendizaje por Refuerzo)

# %% [markdown]
# - Reinforcement Learning es un conjunto de modelos y algoritmos que permiten resolver problemas de tomas de decisiones.
# - Se enfocan en obtener el conjunto de acciones que permitan obtener la mejor salida posible.
# - A diferencia de los modelos de aprendizaje supervisado, en estos casos no hay una solución inequívoca o una única respuesta correcta.
# - Ejemplos
#     - En una partida de ajedrez, no existe un único conjunto de movimientos que permita ganar una partida.
#     - Si queremos que un robot cuadrúpedo camine, no tenemos conocimiento previo de cuáles son las acciones correctas que le permitan caminar.
#     - [DeepMind](https://www.youtube.com/watch?v=V1eYniJ0Rnk)

# %% [markdown]
# Elementos principales de modelos RL
#
# - **Agente**: Es el elemento encargado de la toma de decisiones. Además es el responsable de aprender qué acciones tomar para lograr el mejor resultado.
# - **Entorno**: Es el mundo en el que opera el agente. Este puede ser real, virtual o cualquier otro elemento con el que el agente interactúe.
# - **Acciones**: Cada agente puede realizar acciones las cuales les permiten interactuar con su entorno.
# - **Estado**: Corresponde a una representación del entorno en un cierto momento. El agente utiliza el estado como contexto para la toma de decisiones y sus correspondientes acciones
# - **Recompensa**: Las recompensas son recibidas por el agente desde el entorno en base a cada acción tomada. Las recompensas pueden ser positivas o negativas en base a un objetivo
# - **Política**: La política es una estrategia que el agente sigue para decidir qué acciones tomar en función de su estado actual. El objetivo del agente es aprender una política óptima que le permita obtener la máxima recompensa posible a lo largo del tiempo.

# %% [markdown]
# # Formalización a través de Procesos de decisión de Markov

# %% [markdown]
# Definimos un Proceso de Decisión de Markov (Markov Decision Process) como una tupla $(S, A, \{P_{sa}\}, \gamma, R)$ donde
#
# - $S$ es el conjunto estados en que se puede encontrar el entorno
# - $A$ es el conjunto de acciones posible que puede realizar el agente
# - $P_{sa}$ son las probabilidades de transición entre estados. Estas se definen para cada estado $s \in S$ y acción $a \in A$. En otras palabras, es la distribución de probabilidades sobre cada estado $s$ al tomar una acción $a$.
# - $\gamma \in [0,1)$ es el factor de descuento
# - $R:S \times A \rightarrow \mathbb{R}$ es la función de recompensa. En ocasiones se escribe como una función solo dependiente del estado, en cuyo caso se anota como $R:S \rightarrow \mathbb{R}$

# %% [markdown]
# Las dinámicas de un proceso de Markov quedan definidas de la siguiente manera:
#
# - Se define un estado inicial $s_0 \in S$, a partir del cual se toma una acción $a_0 \in A$.
# - Resultado de la decisión $a_0$, se transiciona aleatoriamente a un estado $s_1$ donde $s_1 \sim P_{s_0 a_0}$.
# - A partir del estado $s_1$, se toma una nueva decisi´on $a_1$.
# - La decisión $a_1$ genera una transición aleatoria a un nuevo estado $s_2 \sim P_{s_1 a_1}$

# %% [markdown]
# <img src="images/MDP_diagram.jpg" alt="" width="800px" align="center"/>

# %% [markdown]
# Para este caso la recompensa total puede ser definida como
#
# $$ R(s_0, a_0)  + \gamma R(s_1, a_1) + \gamma^2 R(s_2, a_2)+ \cdots$$
#
# o, reescribiendo como función dependiente de los estados
#
# $$ R(s_0)  + \gamma R(s_1) + \gamma^2 R(s_2)+ \cdots$$
#
# El objetivo del aprendizaje por refuerzo es **determinar el conjunto de acciones que maximizan la esperanza de la recompensa**
#
# $$ E [ R(s_0)  + \gamma R(s_1) + \gamma^2 R(s_2)+ \cdots ]$$

# %% [markdown]
# - Considere una función de poliza $\pi: S \rightarrow A$, la cual mapea cada estado a una acción. Es posible definir la recompensa obtenida en base a esa poliza y un cierto estado inicial como
#
# $$ V^{\pi}(s) =  E [ R(s_0)  + \gamma R(s_1) + \gamma^2 R(s_2)+ \cdots | s_0 = s, \pi]$$
#
# - Esta puede ser reescrita en su forma de "ecuación de Bellman" como sigue
#
# $$ V^{\pi}(s) = R(s) + \gamma \sum_{s' \in S} P_{s \pi(s)}(s') V^{\pi}(s') $$

# %% [markdown]
# # Mundo Grilla

# %% [markdown]
# Consideremos el siguiente caso.
#
# - Movimientos posibles: Arriba ($\uparrow$), abajo ($\downarrow$), izquierda ($\leftarrow$) y derecha ($\rightarrow$)
# - Casillas +1 y -1 corresponden a las casillas de salida con recompensas del mismo valor
# - Objetivo: terminar el juego con la mayor puntuación posible

# %% [markdown]
# <img src="images/MundoGrilla.drawio.png" alt="" width="400px" align="center"/>

# %% [markdown]
# Se define la siguiente política $\pi$ para cada estado de la grilla

# %% [markdown]
# <img src="images/MundoGrilla_politica.drawio.png" alt="" width="400px" align="center"/>

# %% [markdown]
# # Mundo Grilla (caso determinista sin descuento)

# %% [markdown]
# - Mejores movimientos desde inicio: $\uparrow, \uparrow, \rightarrow, \rightarrow, \rightarrow$

# %% [markdown]
# <img src="images/MundoGrilla_determinista.drawio.png" alt="" width="400px" align="center"/>

# %% [markdown]
# # Mundo Grilla (caso determinista con descuento)

# %% [markdown]
# <img src="images/MundoGrilla_determinsta_descuentos.drawio.png" alt="" width="400px" align="center"/>

# %% [markdown]
# - Los casos anteriores representan situaciones deterministas donde cada acción a realizar por el agente tiene un 100% de probabilidad de éxito (sin errores).
# - La ecuación de Bellman permite también considerar casos en donde el agente puede cometer errores.

# %% [markdown]
# <img src="images/MDP_estocastico_vs_determinista.png" alt="" width="400px" align="center"/>

# %% [markdown]
# Considere ahora que los movimientos del agente no son confiables, es decir **tienen cierta probabilidad**.
# Considere las siguietens probabilidades
# - $80\%$ de ir a la dirección deseada
# - $10\%$ de ir a la izquierda de la dirección deseada
# - $10\%$ de ir a la derecha de la dirección deseada
#
# Ejemplo:
# - $P(\uparrow|\uparrow)=0.8,  P(\leftarrow|\uparrow)=0.1, P(\rightarrow|\uparrow)=0.1$
#
# **¿Cómo podemos calcular las recompensas de cada casilla?** R: Algoritmo Value Iteration

# %% [markdown]
# <img src="images/MundoGrilla_probabilistica.drawio.png" alt="" width="400px" align="center"/>

# %% [markdown]
# # Algoritmo Value Iteration
#
# - Para cada estado $s$, inicializar $V(s):=0$
# - Repetir hasta la convergencia lo siguiente
#     - Por cada estado, actualizar $V(s):=R(s) + \max_{a \in A} \gamma \sum_{s'} P_{sa}(s')V(s')$
#
#
# Esto no solo permite calcular los valores de recompensa esperada por cada estado, sino que también permite obtener la mejor política para el conjunto de estados (policy iteration)
#
# - Inicializar $\pi$ aleatoriamente
# - Repetir hasta la convergencia lo siguiente
#     - Por cada estado $s$ $\pi(s):= \text{argmax}_{a \in A} P_{sa}(s')V(s')$

# %% [markdown]
# # Q Learning
#
# - Hasta el momento, hemos supuesto que las recompensas y las probabilidades de acción son conocidas. ¿Cómo cambia nuestro planteamiento si no conocemos estos datos?
# - En ese caso, debemos descubrir sus valores en base a la **experiencia** (muestras).
# - Para ello calcularemos para cada combinación de estado/acción cuáles son las recompensas esperadas en base a las muestras (valores Q). Estos se calculan con la siguiente fórmula
#
#     $$Q(s,a) := Q(s,a) + \alpha \big[ R(s,a) + \gamma \max_{a'} Q(s',a') - Q(s,a) \big] $$
#
# Donde encontramos la siguiente relación entre los valores $Q$ y los elementos previamente calculados
#
# $$ V(s) = \max_{a}(R(s,a) + \gamma \sum_{s'} P_{sa}(s') V(s')) = \max_{a}(Q(s,a))$$
# $$ \pi(s) = \argmax_{a}(Q(s,a))$$
# - $Q$ viene de quality, pues mide la calidad de las acciones que tomamos a partir de un cierto estado.

# %% [markdown]
# # Deep Q Learning

# %% [markdown]
# - Si bien, el modelo Q Learning funciona correctamente, no escala bien en relación a la cantidad de estados y acciones.
# - Por ello, se plantean los modelos de redes neuronales como alternativa para la obtención de los valores Q (Deep Q Learning).
# - Los valores obtenidos por el algoritmo Q Learning, son utilizados como base para una red neuronal. Esta red neuronal recibe como entrada los valores del estado del entorno, y retorna los valores Q para todas las acciones disponibles.

# %% [markdown]
# <img src="images/q-learning.png" alt="" width="400px" align="center"/>
# <img src="images/deep-q-learning.png" alt="" width="400px" align="center"/>
#
# Source: https://www.geeksforgeeks.org/deep-q-learning/

# %% [markdown]
# ### Funcionamiento de Deep Q-Learning (DQN)
#
# * En **Deep Q-Learning**, una **red neuronal** se utiliza para aproximar los valores ( $Q(s,a)$ ) en lugar de almacenarlos en una tabla.
# * Para cada par de **estado–acción** $((s,a))$, la red predice un **Q-Value estimado**, que representa qué tan buena es esa acción en ese estado.
# * Usando la **ecuación de Bellman**, podemos definir un valor objetivo (*target*) que queremos que la red aprenda:
#
# $$Q_{\text{target}}(s,a) = R(s,a) + \gamma \max_{a'} Q_{\theta}(s', a')$$
#
# * Este ($Q_{\text{target}}$) combina la **recompensa inmediata** ($R(s,a)$) con el **mejor valor futuro estimado** desde el nuevo estado ($s'$).
# * El entrenamiento de la red consiste en **ajustar sus pesos** ($\theta$) para minimizar la diferencia entre su predicción actual ($Q_{\theta}(s,a)$) y el valor objetivo ($Q_{\text{target}}(s,a)$)

# %% [markdown]
# # OpenAI Gymnasium

# %% [markdown]
# - Biblioteca Python de OpenAI (originalmente llamada Gym)
# - Permite con una interfaz sencilla interactuar con diferentes entornos para la prueba de modelos de Aprendizaje por Refuerzo utilizando una API común para todos ellos.
# - Se puede instalar en un entorno virtual a través de pip con `pip install gymnasium`
# - Gymnasium posee múltiples entornos los que se pueden instalar manualmente. Si desea instarlos todos, puede hacerlo a través del comando pip a continuación: `pip install gymnasium[all]`
# - Documentación disponible [aquí](https://gymnasium.farama.org/)

# %% [markdown]
# ## Ejemplo de uso Gymnasium

# %%
# Se importa la biblioteca
import gymnasium as gym
# Se crea uno de los entornos a través de make
        # Se puede obtener un renderizado (visualización) del juego a través de
# .make("EnvName", render_mode="human")
env = gym.make("CartPole-v1", render_mode="human")

# Una vez creado el entorno, obtenemos el estado inicial (primera observación)
# usando env.reset()
observation, info = env.reset()

# El entorno mantiene almacenado los valores posibles tanto de acciones como de observaciones (estados)
# Las acciones se mantienen en env.action_space y las observaciones en env.observation_space
for _ in range(300):
    # Probamos nuestro entorno con acciones aleatorias
    # A partir del action_space obtenemos una muestra de una acción
    action = env.action_space.sample()  # agent policy that uses the observation and info
    
    # Utilizamos esa acción para el siguiente step de evaluación. Como resultado
    # obtenemos una nueva observación del estado del entorno y una recompensa.
    # La función env.step(action) devuelve:
    # - observation: el nuevo estado del entorno tras ejecutar la acción.
    # - reward: la recompensa obtenida por dicha acción.
    # - terminated: True si el episodio terminó porque se alcanzó un estado final.
    # - truncated: True si el episodio se detuvo por límite de tiempo u otra condición.
    # - info: diccionario con información adicional del entorno.
    observation, reward, terminated, truncated, info = env.step(action)
    if terminated or truncated:
        observation, info = env.reset()

# Finalmente cerramos el entorno al terminar la ejecución        
env.close()

# %%
# DQN sencillo para CartPole-v1 (Gymnasium)

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # (opcional) usar GPU 0

import random
from collections import deque
import numpy as np
import gymnasium as gym
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# Ajustes de GPU para utilizar solo la memoria vram necesaria (opcional)
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.set_visible_devices(gpus[0], 'GPU')
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e:
        print("Aviso TF:", e)

# Hiperparámetros
ENV_NAME = "CartPole-v1"
GAMMA = 0.99
LR = 1e-3
EPS_START, EPS_END, EPS_DECAY = 1.0, 0.01, 0.995
BATCH_SIZE = 64
MEM_CAPACITY = 50000
TARGET_UPDATE_EVERY = 200  # pasos
EPISODES = 300
MAX_STEPS = 500
CHECKPOINT_PATH = "dqn_cartpole.weights.h5"
SAVE_EVERY = 50  # guardar cada 50 episodios

# Red Q y Red Target
def build_q_network(input_dim=4, n_actions=2, lr=LR):
    model = Sequential([
        Dense(64, activation='relu', input_shape=(input_dim,)),
        Dense(64, activation='relu'),
        Dense(n_actions, activation='linear')
    ])
    model.compile(optimizer=Adam(lr), loss=tf.keras.losses.Huber())
    return model

# Utilidades DQN
class ReplayBuffer: # memoria
    def __init__(self, capacity):
        self.buf = deque(maxlen=capacity)
    def push(self, s, a, r, ns, done):
        self.buf.append((s, a, r, ns, done))
    def sample(self, batch_size):
        minibatch = random.sample(self.buf, batch_size)
        s, a, r, ns, d = map(np.array, zip(*minibatch))
        # Asegurar shapes (N,4) y (N,)
        return (np.vstack(s), a, r.astype(np.float32),
                np.vstack(ns), d.astype(np.float32))
    def __len__(self):
        return len(self.buf)

# Selección de acciones 
def epsilon_greedy_action(model, state, epsilon, n_actions):
    if np.random.rand() < epsilon:
        return np.random.randint(n_actions)
    q = model.predict(state[None, :], verbose=0)
    return int(np.argmax(q[0]))

# Actualización de red
def hard_update(target_model, online_model):
    target_model.set_weights(online_model.get_weights())

# Entrenamiento
env = gym.make(ENV_NAME)
n_actions = env.action_space.n
state_dim = env.observation_space.shape[0]

q_net = build_q_network(state_dim, n_actions)
target_net = build_q_network(state_dim, n_actions)
hard_update(target_net, q_net)

buffer = ReplayBuffer(MEM_CAPACITY)

epsilon = EPS_START
global_step = 0

for ep in range(1, EPISODES + 1):
    state, _ = env.reset()
    total_reward = 0.0

    for t in range(MAX_STEPS):
        global_step += 1

        # 1) Política ε-greedy para selección de acción
        action = epsilon_greedy_action(q_net, state, epsilon, n_actions)

        # 2) Paso en el entorno aplicando acción seleccionado
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        total_reward += reward

        # 3) Guardar transición en la memoria
        buffer.push(state, action, reward, next_state, float(done))

        # 4) Verifica si hay muestras suficientes en el buffer para entrenar el modelo
        if len(buffer) >= BATCH_SIZE:
            s, a, r, ns, d = buffer.sample(BATCH_SIZE)

            # Q target: r + gamma * (1-done) * max_a' Q_target(ns, a')
            q_next = target_net.predict(ns, verbose=0)              # (N, n_actions)
            max_q_next = np.max(q_next, axis=1)                     # (N,)
            target = r + GAMMA * (1.0 - d) * max_q_next             # (N,)

            # Q online actual
            q_curr = q_net.predict(s, verbose=0)                    # (N, n_actions)
            q_curr[range(BATCH_SIZE), a] = target                   # actualizar solo la acción tomada

            # Fit un paso
            q_net.fit(s, q_curr, epochs=1, verbose=0, batch_size=BATCH_SIZE)

        # 5) Actualización periódica de la red target
        if global_step % TARGET_UPDATE_EVERY == 0:
            hard_update(target_net, q_net)

        state = next_state
        if done:
            break

    # Decaimiento de epsilon por episodio
    epsilon = max(EPS_END, epsilon * EPS_DECAY)

    # Guardar checkpoint periódicamente
    if ep % SAVE_EVERY == 0:
        q_net.save_weights(CHECKPOINT_PATH)
        print(f"Checkpoint guardado en {CHECKPOINT_PATH}")

    print(f"Episodio {ep:3d} | Recompensa: {total_reward:5.1f} | ε={epsilon:.3f}")

env.close()
# Out:
# Episodio   1 | Recompensa:  13.0 | ε=0.995
# Episodio   2 | Recompensa:  38.0 | ε=0.990
# Episodio   3 | Recompensa:  25.0 | ε=0.985
# Episodio   4 | Recompensa:  34.0 | ε=0.980
# Episodio   5 | Recompensa:  34.0 | ε=0.975
# Episodio   6 | Recompensa:  20.0 | ε=0.970
# Episodio   7 | Recompensa:  22.0 | ε=0.966
# Episodio   8 | Recompensa:  71.0 | ε=0.961
# Episodio   9 | Recompensa:  23.0 | ε=0.956
# Episodio  10 | Recompensa:  43.0 | ε=0.951
# Episodio  11 | Recompensa:  20.0 | ε=0.946
# Episodio  12 | Recompensa:  15.0 | ε=0.942
# Episodio  13 | Recompensa:  15.0 | ε=0.937
# Episodio  14 | Recompensa:  17.0 | ε=0.932
# Episodio  15 | Recompensa:  47.0 | ε=0.928
# Episodio  16 | Recompensa:  12.0 | ε=0.923
# Episodio  17 | Recompensa:  20.0 | ε=0.918
# Episodio  18 | Recompensa:  21.0 | ε=0.914
# Episodio  19 | Recompensa:  20.0 | ε=0.909
# Episodio  20 | Recompensa:  64.0 | ε=0.905
# Episodio  21 | Recompensa:  24.0 | ε=0.900
# Episodio  22 | Recompensa:  27.0 | ε=0.896
# Episodio  23 | Recompensa:  28.0 | ε=0.891
# Episodio  24 | Recompensa:  17.0 | ε=0.887
# Episodio  25 | Recompensa:  15.0 | ε=0.882
# Episodio  26 | Recompensa:  15.0 | ε=0.878
# Episodio  27 | Recompensa:  13.0 | ε=0.873
# Episodio  28 | Recompensa:  19.0 | ε=0.869
# Episodio  29 | Recompensa:  46.0 | ε=0.865
# Episodio  30 | Recompensa:  13.0 | ε=0.860
# Episodio  31 | Recompensa:  29.0 | ε=0.856
# Episodio  32 | Recompensa:  19.0 | ε=0.852
# Episodio  33 | Recompensa:  16.0 | ε=0.848
# Episodio  34 | Recompensa:  38.0 | ε=0.843
# Episodio  35 | Recompensa:  29.0 | ε=0.839
# Episodio  36 | Recompensa:  42.0 | ε=0.835
# Episodio  37 | Recompensa:  85.0 | ε=0.831
# Episodio  38 | Recompensa:  66.0 | ε=0.827
# Episodio  39 | Recompensa:  27.0 | ε=0.822
# Episodio  40 | Recompensa:  24.0 | ε=0.818
# Episodio  41 | Recompensa:  15.0 | ε=0.814
# Episodio  42 | Recompensa:  45.0 | ε=0.810
# Episodio  43 | Recompensa:  15.0 | ε=0.806
# Episodio  44 | Recompensa:  74.0 | ε=0.802
# Episodio  45 | Recompensa:  18.0 | ε=0.798
# Episodio  46 | Recompensa:  26.0 | ε=0.794
# Episodio  47 | Recompensa:  24.0 | ε=0.790
# Episodio  48 | Recompensa:  20.0 | ε=0.786
# Episodio  49 | Recompensa:  57.0 | ε=0.782
# Checkpoint guardado en dqn_cartpole.weights.h5
# Episodio  50 | Recompensa: 136.0 | ε=0.778
# Episodio  51 | Recompensa:  28.0 | ε=0.774
# Episodio  52 | Recompensa:  13.0 | ε=0.771
# Episodio  53 | Recompensa:  15.0 | ε=0.767
# Episodio  54 | Recompensa:  18.0 | ε=0.763
# Episodio  55 | Recompensa:  37.0 | ε=0.759
# Episodio  56 | Recompensa:  41.0 | ε=0.755
# Episodio  57 | Recompensa: 112.0 | ε=0.751
# Episodio  58 | Recompensa:  20.0 | ε=0.748
# Episodio  59 | Recompensa:  28.0 | ε=0.744
# Episodio  60 | Recompensa:  82.0 | ε=0.740
# Episodio  61 | Recompensa:  30.0 | ε=0.737
# Episodio  62 | Recompensa:  88.0 | ε=0.733
# Episodio  63 | Recompensa:  53.0 | ε=0.729
# Episodio  64 | Recompensa:  53.0 | ε=0.726
# Episodio  65 | Recompensa:  59.0 | ε=0.722
# Episodio  66 | Recompensa:  64.0 | ε=0.718
# Episodio  67 | Recompensa:  70.0 | ε=0.715
# Episodio  68 | Recompensa:  19.0 | ε=0.711
# Episodio  69 | Recompensa:  54.0 | ε=0.708
# Episodio  70 | Recompensa:  41.0 | ε=0.704
# Episodio  71 | Recompensa:  22.0 | ε=0.701
# Episodio  72 | Recompensa:  71.0 | ε=0.697
# Episodio  73 | Recompensa:  32.0 | ε=0.694
# Episodio  74 | Recompensa:  13.0 | ε=0.690
# Episodio  75 | Recompensa:  69.0 | ε=0.687
# Episodio  76 | Recompensa:  14.0 | ε=0.683
# Episodio  77 | Recompensa: 117.0 | ε=0.680
# Episodio  78 | Recompensa:  91.0 | ε=0.676
# Episodio  79 | Recompensa:  67.0 | ε=0.673
# Episodio  80 | Recompensa:  16.0 | ε=0.670
# Episodio  81 | Recompensa:  22.0 | ε=0.666
# Episodio  82 | Recompensa:  21.0 | ε=0.663
# Episodio  83 | Recompensa:  14.0 | ε=0.660
# Episodio  84 | Recompensa:  23.0 | ε=0.656
# Episodio  85 | Recompensa:  30.0 | ε=0.653
# Episodio  86 | Recompensa:  20.0 | ε=0.650
# Episodio  87 | Recompensa:  61.0 | ε=0.647
# Episodio  88 | Recompensa:  21.0 | ε=0.643
# Episodio  89 | Recompensa:  57.0 | ε=0.640
# Episodio  90 | Recompensa:  83.0 | ε=0.637
# Episodio  91 | Recompensa:  58.0 | ε=0.634
# Episodio  92 | Recompensa:  58.0 | ε=0.631
# Episodio  93 | Recompensa: 114.0 | ε=0.627
# Episodio  94 | Recompensa: 259.0 | ε=0.624
# Episodio  95 | Recompensa:  17.0 | ε=0.621
# Episodio  96 | Recompensa: 121.0 | ε=0.618
# Episodio  97 | Recompensa:  47.0 | ε=0.615
# Episodio  98 | Recompensa:  70.0 | ε=0.612
# Episodio  99 | Recompensa:  73.0 | ε=0.609
# Checkpoint guardado en dqn_cartpole.weights.h5
# Episodio 100 | Recompensa: 136.0 | ε=0.606
# Episodio 101 | Recompensa:  75.0 | ε=0.603
# Episodio 102 | Recompensa:  89.0 | ε=0.600
# Episodio 103 | Recompensa:  27.0 | ε=0.597
# Episodio 104 | Recompensa:  26.0 | ε=0.594
# Episodio 105 | Recompensa:  12.0 | ε=0.591
# Episodio 106 | Recompensa:  15.0 | ε=0.588
# Episodio 107 | Recompensa:  14.0 | ε=0.585
# Episodio 108 | Recompensa:  10.0 | ε=0.582
# Episodio 109 | Recompensa:  79.0 | ε=0.579
# Episodio 110 | Recompensa:  36.0 | ε=0.576
# Episodio 111 | Recompensa:  30.0 | ε=0.573
# Episodio 112 | Recompensa: 144.0 | ε=0.570
# Episodio 113 | Recompensa:  26.0 | ε=0.568
# Episodio 114 | Recompensa:  19.0 | ε=0.565
# Episodio 115 | Recompensa:  11.0 | ε=0.562
# Episodio 116 | Recompensa:  36.0 | ε=0.559
# Episodio 117 | Recompensa:  28.0 | ε=0.556
# Episodio 118 | Recompensa:  30.0 | ε=0.554
# Episodio 119 | Recompensa:  23.0 | ε=0.551
# Episodio 120 | Recompensa: 161.0 | ε=0.548
# Episodio 121 | Recompensa:  32.0 | ε=0.545
# Episodio 122 | Recompensa:  12.0 | ε=0.543
# Episodio 123 | Recompensa:  17.0 | ε=0.540
# Episodio 124 | Recompensa:  14.0 | ε=0.537
# Episodio 125 | Recompensa:  13.0 | ε=0.534
# Episodio 126 | Recompensa: 109.0 | ε=0.532
# Episodio 127 | Recompensa:  28.0 | ε=0.529
# Episodio 128 | Recompensa:  26.0 | ε=0.526
# Episodio 129 | Recompensa:  90.0 | ε=0.524
# Episodio 130 | Recompensa:  15.0 | ε=0.521
# Episodio 131 | Recompensa:  14.0 | ε=0.519
# Episodio 132 | Recompensa:  71.0 | ε=0.516
# Episodio 133 | Recompensa:  10.0 | ε=0.513
# Episodio 134 | Recompensa:  31.0 | ε=0.511
# Episodio 135 | Recompensa:  22.0 | ε=0.508
# Episodio 136 | Recompensa: 109.0 | ε=0.506
# Episodio 137 | Recompensa:  16.0 | ε=0.503
# Episodio 138 | Recompensa:  34.0 | ε=0.501
# Episodio 139 | Recompensa:  76.0 | ε=0.498
# Episodio 140 | Recompensa:  29.0 | ε=0.496
# Episodio 141 | Recompensa:  50.0 | ε=0.493
# Episodio 142 | Recompensa:  13.0 | ε=0.491
# Episodio 143 | Recompensa:  12.0 | ε=0.488
# Episodio 144 | Recompensa:  12.0 | ε=0.486
# Episodio 145 | Recompensa:  31.0 | ε=0.483
# Episodio 146 | Recompensa:  13.0 | ε=0.481
# Episodio 147 | Recompensa:  15.0 | ε=0.479
# Episodio 148 | Recompensa:  96.0 | ε=0.476
# Episodio 149 | Recompensa:  20.0 | ε=0.474
# Checkpoint guardado en dqn_cartpole.weights.h5
# Episodio 150 | Recompensa:  30.0 | ε=0.471
# Episodio 151 | Recompensa:  19.0 | ε=0.469
# Episodio 152 | Recompensa:  25.0 | ε=0.467
# Episodio 153 | Recompensa:  25.0 | ε=0.464
# Episodio 154 | Recompensa:  12.0 | ε=0.462
# Episodio 155 | Recompensa:  14.0 | ε=0.460
# Episodio 156 | Recompensa:  10.0 | ε=0.458
# Episodio 157 | Recompensa:  28.0 | ε=0.455
# Episodio 158 | Recompensa: 104.0 | ε=0.453
# Episodio 159 | Recompensa:  24.0 | ε=0.451
# Episodio 160 | Recompensa:  31.0 | ε=0.448
# Episodio 161 | Recompensa:  21.0 | ε=0.446
# Episodio 162 | Recompensa:  40.0 | ε=0.444
# Episodio 163 | Recompensa:  37.0 | ε=0.442
# Episodio 164 | Recompensa:  21.0 | ε=0.440
# Episodio 165 | Recompensa:  14.0 | ε=0.437
# Episodio 166 | Recompensa:  14.0 | ε=0.435
# Episodio 167 | Recompensa:  39.0 | ε=0.433
# Episodio 168 | Recompensa:  16.0 | ε=0.431
# Episodio 169 | Recompensa: 101.0 | ε=0.429
# Episodio 170 | Recompensa:  13.0 | ε=0.427
# Episodio 171 | Recompensa:  40.0 | ε=0.424
# Episodio 172 | Recompensa:  35.0 | ε=0.422
# Episodio 173 | Recompensa:  99.0 | ε=0.420
# Episodio 174 | Recompensa:  20.0 | ε=0.418
# Episodio 175 | Recompensa:  26.0 | ε=0.416
# Episodio 176 | Recompensa:  21.0 | ε=0.414
# Episodio 177 | Recompensa:  93.0 | ε=0.412
# Episodio 178 | Recompensa:  15.0 | ε=0.410
# Episodio 179 | Recompensa:  39.0 | ε=0.408
# Episodio 180 | Recompensa:  16.0 | ε=0.406
# Episodio 181 | Recompensa:  22.0 | ε=0.404
# Episodio 182 | Recompensa:  16.0 | ε=0.402
# Episodio 183 | Recompensa:  20.0 | ε=0.400
# Episodio 184 | Recompensa:  14.0 | ε=0.398
# Episodio 185 | Recompensa:  32.0 | ε=0.396
# Episodio 186 | Recompensa:  24.0 | ε=0.394
# Episodio 187 | Recompensa:  33.0 | ε=0.392
# Episodio 188 | Recompensa:  20.0 | ε=0.390
# Episodio 189 | Recompensa:  23.0 | ε=0.388
# Episodio 190 | Recompensa:  10.0 | ε=0.386
# Episodio 191 | Recompensa:  37.0 | ε=0.384
# Episodio 192 | Recompensa:  58.0 | ε=0.382
# Episodio 193 | Recompensa:  18.0 | ε=0.380
# Episodio 194 | Recompensa: 118.0 | ε=0.378
# Episodio 195 | Recompensa:  27.0 | ε=0.376
# Episodio 196 | Recompensa:  26.0 | ε=0.374
# Episodio 197 | Recompensa: 111.0 | ε=0.373
# Episodio 198 | Recompensa:  12.0 | ε=0.371
# Episodio 199 | Recompensa:  90.0 | ε=0.369
# Checkpoint guardado en dqn_cartpole.weights.h5
# Episodio 200 | Recompensa:  96.0 | ε=0.367
# Episodio 201 | Recompensa:  47.0 | ε=0.365
# Episodio 202 | Recompensa:  58.0 | ε=0.363
# Episodio 203 | Recompensa:  16.0 | ε=0.361
# Episodio 204 | Recompensa:  45.0 | ε=0.360
# Episodio 205 | Recompensa:  13.0 | ε=0.358
# Episodio 206 | Recompensa:  56.0 | ε=0.356
# Episodio 207 | Recompensa:   9.0 | ε=0.354
# Episodio 208 | Recompensa:  17.0 | ε=0.353
# Episodio 209 | Recompensa:  11.0 | ε=0.351
# Episodio 210 | Recompensa:  53.0 | ε=0.349
# Episodio 211 | Recompensa:  11.0 | ε=0.347
# Episodio 212 | Recompensa:  16.0 | ε=0.346
# Episodio 213 | Recompensa:  41.0 | ε=0.344
# Episodio 214 | Recompensa:  24.0 | ε=0.342
# Episodio 215 | Recompensa:  14.0 | ε=0.340
# Episodio 216 | Recompensa:  12.0 | ε=0.339
# Episodio 217 | Recompensa:  13.0 | ε=0.337
# Episodio 218 | Recompensa:  98.0 | ε=0.335
# Episodio 219 | Recompensa:  18.0 | ε=0.334
# Episodio 220 | Recompensa:  17.0 | ε=0.332
# Episodio 221 | Recompensa:  23.0 | ε=0.330
# Episodio 222 | Recompensa:  17.0 | ε=0.329
# Episodio 223 | Recompensa:  32.0 | ε=0.327
# Episodio 224 | Recompensa:  15.0 | ε=0.325
# Episodio 225 | Recompensa:  12.0 | ε=0.324
# Episodio 226 | Recompensa:  38.0 | ε=0.322
# Episodio 227 | Recompensa:  35.0 | ε=0.321
# Episodio 228 | Recompensa:  27.0 | ε=0.319
# Episodio 229 | Recompensa:  15.0 | ε=0.317
# Episodio 230 | Recompensa:  48.0 | ε=0.316
# Episodio 231 | Recompensa:  23.0 | ε=0.314
# Episodio 232 | Recompensa:  39.0 | ε=0.313
# Episodio 233 | Recompensa: 102.0 | ε=0.311
# Episodio 234 | Recompensa:  98.0 | ε=0.309
# Episodio 235 | Recompensa:  18.0 | ε=0.308
# Episodio 236 | Recompensa:  97.0 | ε=0.306
# Episodio 237 | Recompensa: 106.0 | ε=0.305
# Episodio 238 | Recompensa:  54.0 | ε=0.303
# Episodio 239 | Recompensa:  96.0 | ε=0.302
# Episodio 240 | Recompensa: 113.0 | ε=0.300
# Episodio 241 | Recompensa: 101.0 | ε=0.299
# Episodio 242 | Recompensa:  32.0 | ε=0.297
# Episodio 243 | Recompensa:  23.0 | ε=0.296
# Episodio 244 | Recompensa:  33.0 | ε=0.294
# Episodio 245 | Recompensa:  12.0 | ε=0.293
# Episodio 246 | Recompensa:  10.0 | ε=0.291
# Episodio 247 | Recompensa:  28.0 | ε=0.290
# Episodio 248 | Recompensa:  11.0 | ε=0.288
# Episodio 249 | Recompensa:  19.0 | ε=0.287
# Checkpoint guardado en dqn_cartpole.weights.h5
# Episodio 250 | Recompensa:  16.0 | ε=0.286
# Episodio 251 | Recompensa:  11.0 | ε=0.284
# Episodio 252 | Recompensa:  12.0 | ε=0.283
# Episodio 253 | Recompensa:  15.0 | ε=0.281
# Episodio 254 | Recompensa:  11.0 | ε=0.280
# Episodio 255 | Recompensa:  15.0 | ε=0.279
# Episodio 256 | Recompensa:  14.0 | ε=0.277
# Episodio 257 | Recompensa:  14.0 | ε=0.276
# Episodio 258 | Recompensa:  25.0 | ε=0.274
# Episodio 259 | Recompensa:  45.0 | ε=0.273
# Episodio 260 | Recompensa:  95.0 | ε=0.272
# Episodio 261 | Recompensa: 105.0 | ε=0.270
# Episodio 262 | Recompensa:  32.0 | ε=0.269
# Episodio 263 | Recompensa:  21.0 | ε=0.268
# Episodio 264 | Recompensa:  13.0 | ε=0.266
# Episodio 265 | Recompensa: 142.0 | ε=0.265
# Episodio 266 | Recompensa:  47.0 | ε=0.264
# Episodio 267 | Recompensa:  38.0 | ε=0.262
# Episodio 268 | Recompensa:  27.0 | ε=0.261
# Episodio 269 | Recompensa:  22.0 | ε=0.260
# Episodio 270 | Recompensa:  61.0 | ε=0.258
# Episodio 271 | Recompensa: 103.0 | ε=0.257
# Episodio 272 | Recompensa: 101.0 | ε=0.256
# Episodio 273 | Recompensa:  16.0 | ε=0.255
# Episodio 274 | Recompensa: 156.0 | ε=0.253
# Episodio 275 | Recompensa:  16.0 | ε=0.252
# Episodio 276 | Recompensa:  54.0 | ε=0.251
# Episodio 277 | Recompensa:  20.0 | ε=0.249
# Episodio 278 | Recompensa:  65.0 | ε=0.248
# Episodio 279 | Recompensa:  19.0 | ε=0.247
# Episodio 280 | Recompensa:  82.0 | ε=0.246
# Episodio 281 | Recompensa:  31.0 | ε=0.245
# Episodio 282 | Recompensa:  13.0 | ε=0.243
# Episodio 283 | Recompensa:  40.0 | ε=0.242
# Episodio 284 | Recompensa:  14.0 | ε=0.241
# Episodio 285 | Recompensa:  14.0 | ε=0.240
# Episodio 286 | Recompensa:  68.0 | ε=0.238
# Episodio 287 | Recompensa:  53.0 | ε=0.237
# Episodio 288 | Recompensa:  51.0 | ε=0.236
# Episodio 289 | Recompensa:  70.0 | ε=0.235
# Episodio 290 | Recompensa:  38.0 | ε=0.234
# Episodio 291 | Recompensa:  62.0 | ε=0.233
# Episodio 292 | Recompensa:  97.0 | ε=0.231
# Episodio 293 | Recompensa:  18.0 | ε=0.230
# Episodio 294 | Recompensa:  13.0 | ε=0.229
# Episodio 295 | Recompensa: 114.0 | ε=0.228
# Episodio 296 | Recompensa: 133.0 | ε=0.227
# Episodio 297 | Recompensa:  77.0 | ε=0.226
# Episodio 298 | Recompensa: 110.0 | ε=0.225
# Episodio 299 | Recompensa: 100.0 | ε=0.223
# Checkpoint guardado en dqn_cartpole.weights.h5
# Episodio 300 | Recompensa:  52.0 | ε=0.222

# %%
# Evaluación del DQN entrenado en CartPole-v1
# Carga pesos guardados y prueba el agente

import numpy as np
import gymnasium as gym
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# Configuración
ENV_NAME = "CartPole-v1"
CHECKPOINT_PATH = "dqn_cartpole.weights.h5"
MAX_STEPS = 500

# Reconstruir la red
# (debe coincidir exactamente con la del entrenamiento)
def build_q_network(input_dim=4, n_actions=2, lr=1e-3):
    model = Sequential([
        Dense(64, activation='relu', input_shape=(input_dim,)),
        Dense(64, activation='relu'),
        Dense(n_actions, activation='linear')
    ])
    model.compile(optimizer=Adam(lr), loss=tf.keras.losses.Huber())
    return model

# Cargar pesos
env = gym.make(ENV_NAME, render_mode="human")  # usa "None" si no quieres render
state_dim = env.observation_space.shape[0]
n_actions = env.action_space.n

model = build_q_network(state_dim, n_actions)
model.load_weights(CHECKPOINT_PATH)
print(f"Pesos cargados desde {CHECKPOINT_PATH}")

# Evaluar episodios
def evaluate(episodes=10):
    rewards = []
    for ep in range(episodes):
        s, _ = env.reset()
        ep_reward = 0.0
        for _ in range(MAX_STEPS):
            q = model.predict(s[None, :], verbose=0)
            a = int(np.argmax(q[0]))  # política greedy (mejor acción)
            s, r, term, trunc, _ = env.step(a)
            ep_reward += r
            if term or trunc:
                break
        rewards.append(ep_reward)
        print(f"Episodio {ep+1}: Recompensa = {ep_reward:.1f}")
    print(f"\nRecompensa promedio en {episodes} episodios: {np.mean(rewards):.1f}")
    return rewards

evaluate(episodes=10)
env.close()
# Out:
# /home/polivares/.local/share/mamba/envs/IPD434/lib/python3.10/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/polivares/.local/share/mamba/envs/IPD434/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Pesos cargados desde dqn_cartpole.weights.h5
# Episodio 1: Recompensa = 155.0
# Episodio 2: Recompensa = 148.0
# Episodio 3: Recompensa = 152.0
# Episodio 4: Recompensa = 137.0
# Episodio 5: Recompensa = 141.0
# Episodio 6: Recompensa = 148.0
# Episodio 7: Recompensa = 143.0
# Episodio 8: Recompensa = 134.0
# Episodio 9: Recompensa = 151.0
# Episodio 10: Recompensa = 150.0
#
# Recompensa promedio en 10 episodios: 145.9

# %%
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")
#codigo extra, para que imagenes de matplotlib
#estén centradas en las diapositivas, ejecutar antes de lanzar los ejemplos.
