# %% [markdown]
# <img src="images/utfsm.png" alt="" width="150px" align="left"/>
# <img src="images/utfsm.png" alt="" width="150px" align="right"/>
# <br/>
# <div align="center">
# <h2>IPD-434 Seminario de Soft Computing</h2><br/>
# <h1>Introducción a la Computación Evolutiva</h1>
# <br/><br/>
# Dr. Nicolás Gálvez Ramírez<br/>
# Dr. Patricio Olivares Roncagliolo<br/><br/>
# Ingeniería Civil Telemática<br/>
# Departamento de Eléctronica<br/>
# Universidad Técnica Federico Santa María
# </div>
#
# Fuente: "Introduction to Evolutionary Computing", Gusz Eiben and James Smith.

# %% [markdown]
# # Resolviendo problemas: Método de la Caja Negra

# %% [markdown]
# Es un método que sirve para clasificar los diversos tipos de problemas que necesitan ser resueltos en la vida real. Se compone de tres elementos:
# * Una entrada, que representa la información de entrada a del sistema;
# * Un modelo, que toma al entrada y la utiliza, transforma y/o modifica; y
# * Una salida, que representa el resultado generado por el modelo.
#
# <center><img src="images/blackbox.png" alt="" width="40%" align="center"/></center>

# %% [markdown]
# ## Tipos de Problemas

# %% [markdown]
# * Problemas de Optimización: Modelo conocido y una salida esperada o especificada, **encontrar la configuración de entrada**.
#
# <center><img src="images/optimizacion.png" alt="" width="60%" align="center"/></center>
#
# * Optimizar.
#
#
# * La salida puede no ser conocida, pero se define lo esperado $\rightarrow$ mínimo o máximo.

# %% [markdown]
# <center><img src="images/optimizacion.png" alt="" width="60%" align="center"/></center>
#
# * Ejemplo: Minimizar los topes de horario en la planificacion semestral de los alumnos.
#     * Modelo: Representación de las asignaciones que representen los ramos, horarios, salas, etc.
#     * Salida: Se espera el menor valor posible $\rightarrow$ 0.
#     * **Entrada**: ¿Qué asignaciones tendremos para las representaciones?
#     * **Entrada**: ¿Que valores nos llevan a nuestra salida esperada en el modelo?

# %% [markdown]
# * Problemas de Modelado: Dadas ciertas entradas y salidas, el objetivo es encontrar un modelo capas de **entregar la salida correcta para cada entrada conocida**, usando **experiencias previas** y **generalizando a instancias desconocidas**.
#
# <center><img src="images/modelado.png" alt="" width="60%" align="center"/></center>
#
# * Aprendizaje.
# * Aprendizaje Estadístico $\rightarrow$ Supervisado.

# %% [markdown]
# <center><img src="images/modelado.png" alt="" width="60%" align="center"/></center>
#
# * Ejemplo: Clasificador de imágenes.
#     * Entrada: Conjunto de Imagenes.
#     * Salida: Conjunto de Etiquetas de las imágenes.
#     * **Modelo**: ¿Qué metodo me permite etiquetar imágenes basado en la experiencia conocida?.

# %% [markdown]
# * Problemas de Simulación: Dada una entrada y modelo, se busca calcular correctamente **la salida a las entradas**.
# <center><img src="images/simulacion.png" alt="" width="60%" align="center"/></center>
#
# * Predicción, Pronósticos.
# * Aprendizaje Estadístico $\rightarrow$ No Supervisado

# %% [markdown]
# <center><img src="images/simulacion.png" alt="" width="60%" align="center"/></center>
#
# * Ejemplo: Pronósticos meteorológicos.
#     * Entrada: Datos meteorológicos actuales e históricos.
#     * Modelo: Modelos de Predición Meteorológica (i.e. proyección del viento, corrientes marinas, etc.)
#     * **Salida**: Datos meteorológicos en un tiempo futuro.

# %% [markdown]
# # Optimización Combinatoria
#
# > Campo de la matemática que busca encontrar el objeto optimo que resuelve a un problema dentro de un conjunto finito de objetos.

# %% [markdown]
# ## Problemas de Optimización Combinatoria
#
# Los problemas de Optimización Combinatoria se pueden clasificar dentro de los primeros dos problemas de tipo caja negra:

# %% [markdown]
# * Problemas de Optmizaición:
#     * Modelo: Modelación Matemática (lineal, cuadrática, lógica primer orden).
#     * Salida: Función de Evaluación (objetivo, fitness, etc)
#     + **Entrada**: Variables, y sus valores, que optimizan la salida.

# %% [markdown]
# * Problemas de Modelado:
#     * Entrada: Data Set.
#     * Salida: Etiquetas (conocidas y aprendidas).
#     * **Modelo**: Sistema que permite etiquetar entradas en salidas con cierto grado de precisión.
#     * _Puede ser re-escrito como un Problema de Optimización_:
#         * Modelo: Modelado estadístico (i.e, regresión)
#         * Salida: Error Cuadrático Medio, Precisión, Coeficiente de Determinación.
#         * **Entrada**: Variables y valores que optimizan la salida.

# %% [markdown]
# ## Problemas de Búsqueda.

# %% [markdown]
# * Los candidatos para resolver estos problemas están ubicados en un espacio de estados el cuál es usualmente finito pero enorme.
# * La resolución de los problemas es una búsqueda a través de un gran conjunto de posibilidades para encontrar una solución.
#     * Flash-back: **Espacio (de Estados) de Búsqueda**.
# * Por lo tanto, los problemas de optimización combinatoria se pueden representar como **problemas de búsqueda**.

# %% [markdown]
# ## Búsqueda
#
# > ___Encontrar, evaluar y aceptar soluciones como candidatos para resolver un problema desde un conjunto con todas las posibles soluciones___.

# %% [markdown]
# ### Encontrar:
#   * **Espacio de Búsqueda** $\rightarrow$ Conjunto de todas las posibles soluciones.
#   * **Espacio de Búsqueda** $\rightarrow$ dominio de todas variables de decisión que definen una solución de un problema.

# %% [markdown]
# ### Evaluar:
#    * Usar una función específica de **evaluación** que cuantifique y compare los candidatos.
#    * _Función Objetivo_, _Función de Evaluación_, _Función de Fitness_.

# %% [markdown]
# ### Aceptar:
#   * Si un **conjunto de restricciones** es satisfecho.

# %% [markdown]
# ## Tipos de Problemas de Búsqueda
#
# Clasificaremos los problemas de búsqueda en 3 tipos.
#
#
# <center><img src="images/cop.png" alt="" width="50%" align="center"/></center>

# %% [markdown]
# ### Problema de Optimización Libre (_Free Optimisation Problem, FOP_)
# > Se busca una solución que optimiza un función de evaluación sin restricciones (más que la estructura de la misma).

# %% [markdown]
# ### Problema de Satisfacción de Restricciones (_Constraint Satisfaction Problem, CSP)
# > Se acepta una solución que cumple con un grupo de restricciones que no optimiza alguna función de evaluación.

# %% [markdown]
# ### Problema de Optimización y Satisfacción de Restricciones (_Constraint Optimisation and Satisfaction Problem, CSOP_)
# ##### a.k.a. Problema de Optimización Restringido (_Constrained Optimisation Problem, COP_)
# > Se busca una solución que optimiza una función de evaluación y cumple con un grupo de restricciones adosadas a ella.

# %% [markdown]
# ### Ejemplo: Problema de las N-Reinas
#
# Problema de Satisfacción de Restricciones (CSP), te tipo puzzle matemático, de complejidad **NP-Complete**, que establece lo siguiente:
#
# > Ubique $n$ reinas en un tablero de ajedrez de dimensiones $n \times n$ de tal forma que no habrá dos reinas que hagan jaque entre ellas.
#
# <center><img src="images/nqueens.png" alt="" width="30%" align="center"/></center>

# %% [markdown]
# ### N-Reinas como FOP
#
# * Representación: Tablero de ajedrez de tamaño $n \times n$.
# </br></br>
# * Espacio de Búsqueda:
#     * $S$: Conjunto de todas las configuraciones del tablero con $n$ reinas en ella.
# </br></br>
# * Función de Evaluación:
#     * $f(s)$: Cantidad de reinas libres de check en el tablero.
# </br></br>
# * Soluciones:
#     * $ S^* = \{ s \in S ~ | ~ f(s) = n \}$
#     * $ S^* \subseteq S$

# %% [markdown]
# ### N-Reinas como CSP
# * Representación: Tablero de ajedrez de tamaño $n \times n$.
# </br></br>
# * Espacio de Búsqueda:
#     * $S$: Conjunto de todas las configuraciones del tablero con $n$ reinas en ella.
# </br></br>
# * Restricción (como predicado):
#     * ```is_checked(s)```$ = \left\{ \begin{array}{ll} \texttt{true} & \text{si } s \in S \text{ tiene dos reinas en check} \\
#                               \texttt{false} & \text{en caso contrario} \end{array} \right.$
# </br></br>
# * Soluciones:
#     * $ S^* = \{ s \in S ~ | $ ```is_checked(s)```$ = \texttt{false} \}$
#     * $ S^* \subseteq S$

# %% [markdown]
# ### N-Reinas como CSOP
#
# * Representación: Tablero de ajedrez de tamaño $n \times n$.
# </br></br>
# * Espacio de Búsqueda:
#     * $S$: Conjunto de todas las configuraciones del tablero con $n$ reinas en ella.
# </br></br>
# * Restricción (como predicado):
#     * ```column(s)```$ = \left\{ \begin{array}{ll} \texttt{true} & \text{si } s \in S \text{ tiene dos reinas en una misma columna} \\
#                               \texttt{false} & \text{en caso contrario} \end{array} \right.$
# </br></br>
#     * ```row(s)```$ = \left\{ \begin{array}{ll} \texttt{true} & \text{si } s \in S \text{ tiene dos reinas en una misma fila} \\
#                               \texttt{false} & \text{en caso contrario} \end{array} \right.$
# </br></br>
# * Función de Evaluación:
#     * $D(s)$: Cantidad de reinas en check por diagonales.
# </br></br>
# * Soluciones:
#     * $ S^* = \{ s \in S ~ | $ ```column(s)```$ = \texttt{false}~ \land $ ```row(s)```$ = \texttt{false}~ \land min(D(s))\}$
#     * $ S^* \subseteq S$

# %% [markdown]
# * La representación de la solución, o modelo, juega un rol fundamental en como se aborda y soluciona el problema.
# * Puede mejorar drásticamente la capacidad de resolución del problema.
# * **Out-of-the-box thinking**.

# %% [markdown]
# ### Tiene que haber obligatoriamente una reina en cada fila y en cada columna. Version 1.
#
# * Representación: Vector de enteros de tamaño $n$, dónde cada elemento representa secuencialmente a cada columna de un tablero de ajedrez de tamaño $n \times n$. El valor en cada elemento corresponde a la fila en la que se ubica una reina.
# </br></br>
# * Espacio de Búsqueda:
#     * $S$: Conjunto de todas los vectores entreros válidos representando un tablero de ajedrez de $n \times n$.
# </br></br>
# * Restricción (como predicado):
#     * ```all_different(s)```$ = \left\{ \begin{array}{ll} \texttt{true} & \text{si } s \in S \text{ no tiene dos elementos del vector que tengan el mismo valor} \\
#                               \texttt{false} & \text{en caso contrario} \end{array} \right.$
# </br></br>
# * Función de Evaluación:
#     * $D(s)$: Cantidad de reinas en check por diagonales.
# </br></br>
# * Soluciones:
#     * $ S^* = \{ s \in S ~ | $ ```all_different(s)```$ = \texttt{false}~ \land min(D(s))\}$
#     * $ S^* \subseteq S$

# %% [markdown]
# ### Tiene que haber obligatoriamente una reina en cada fila y en cada columna. Version 2.
#
# * Representación: Vector de enteros de tamaño $n$, dónde cada elemento representa secuencialmente a cada columna de un tablero de ajedrez de tamaño $n \times n$. El valor en cada elemento corresponde a la fila en la que se ubica una reina.
# </br></br>
# * Espacio de Búsqueda:
#     * $S$: Conjunto de todas los vectores entreros que no repiten valores.
# </br></br>
# * Función de Evaluación:
#     * $D(s)$: Cantidad de reinas en check por diagonales.
# </br></br>
# * Soluciones:
#     * $ S^* = \{ s \in S ~ | min(D(s))\}$
#     * $ S^* \subseteq S$

# %% [markdown]
# # Paradigmas de Búsqueda
# ### a.k.a. Hard Computing vs Soft Computing en Optimización Combinatoria
#
# Existen distintos paradigmas para afrontar encontrar soluciones en el espacio de búsqueda, las podemos resumir en las siguientes:

# %% [markdown]
# ### Aproximación Sistémica vs Busqueda Local
#
# * Aproximación Sistémica:
#     * Completitud.
#     * Búsqueda sobre sistmémica sobre el espacio de búsqueda, garantizando:
#         * Solución optima, o que
#         * No existe solución.
#     * Computacionalmente costoso.
# </br></br>
#
#
# * Búsqueda Local:
#     * Incompletitud.
#     * Búsqueda parcial sobre diferentes sub-espacios del espacio de busqueda.No puede garantizar:
#         * Solución optima.
#         * Solución factible.
#         * No existe solución.
#     * Computacionalmente rápida.

# %% [markdown]
# ### Búsqueda Constructiva vs Búsqueda Perturbativa.
# * Búsqueda Constructiva
#     * Encontrar la solución desde un inicio vacío.
#     * Generalmente, soluciones incompletas.
# </br></br>
# * Búqueda Perturbativa
#     * Encontrar la solución modificando una existente.
#     * Generalmente, mejoras sobre una solución factible de baja calidad.

# %% [markdown]
# ## Heurísticas
# * Greedy

# %% [markdown]
# # Metaheurísticas

# %% [markdown]
# ## Búsqueda Local
#
# * Monocandidato.
#
# * Conceptos Claves:
#     * Movimiento: Heurísitca
#     * Vecindario.
#     * Criterios de Término.
#
# * Algoritmos:
#     * HC, SA, TS, GRASP, ILS.
#
# * Optimización Multi-objetivo.
# * Configuración de Parámetros.

# %% [markdown]
# # Computación Evolutiva

# %% [markdown]
# ## Características
#
# * Población
# * Operadores
# * Generaciones
# * Evaluación

# %% [markdown]
# ## Tipos de Algoritmos

# %% [markdown]
# ### Programación Evolutiva

# %% [markdown]
# ### Estrategias de Evolución

# %% [markdown]
# ### Algortimos Genéticos

# %% [markdown]
# ### Programación Genética

# %% [markdown]
# ## Derivaciones

# %% [markdown]
# ### Co-Evolución

# %% [markdown]
# ### Algoritmos Bío-Inspirados
